# %% [markdown]
# <a href="https://colab.research.google.com/github/dheeraj-iitk/BCS-summer-project/blob/main/Assignments/ML_ASSIGNMENT_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Question 1 : Linear Regression
# To check whether you are able to build simple linear regression model from scratch or not.

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# !wget --no-check-certificate https://github.com/adigup390/datasets/raw/main/X.npy -O X.npy
# !wget --no-check-certificate https://github.com/adigup390/datasets/raw/main/y.npy -O y.npy
# Out:
# --2021-05-27 09:49:33--  https://github.com/adigup390/datasets/raw/main/X.npy
# Resolving github.com (github.com)... 52.69.186.44
# Connecting to github.com (github.com)|52.69.186.44|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/adigup390/datasets/main/X.npy [following]
# --2021-05-27 09:49:33--  https://raw.githubusercontent.com/adigup390/datasets/main/X.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 528 [application/octet-stream]
# Saving to: ‘X.npy’
#
# X.npy               100%[===================>]     528  --.-KB/s    in 0s
#
# 2021-05-27 09:49:33 (23.8 MB/s) - ‘X.npy’ saved [528/528]
#
# --2021-05-27 09:49:33--  https://github.com/adigup390/datasets/raw/main/y.npy
# Resolving github.com (github.com)... 13.114.40.48
# Connecting to github.com (github.com)|13.114.40.48|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/adigup390/datasets/main/y.npy [following]
# --2021-05-27 09:49:34--  https://raw.githubusercontent.com/adigup390/datasets/main/y.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 528 [application/octet-stream]
# Saving to: ‘y.npy’
#
# y.npy               100%[===================>]     528  --.-KB/s    in 0s
#
# 2021-05-27 09:49:34 (23.0 MB/s) - ‘y.npy’ saved [528/528]

# %%
def load_data_LR():
  # Implement this function to read the dataset using the path declared in path_X and path_y
  # should return the X and y data
  # use np.load() to load the data google it you will get to know how to do it

  path_X = "X.npy"
  path_y = "y.npy"

  # Write your code here ----------
  X=np.load(path_X)
  y=np.load(path_y)
  # -------------------------------

  return X, y

# %%
def get_linear_model(X, y):
  # This shoudl return a proper linear model without bias of type y = XW

  # Write your code here ----------
  
  # -------------------------------
  
  W = np.random.randn(D, out_shape)
  W=np.dot(y,np.linalg.inv(X))
  return W

# %%
def MSE(y, y_pred):
  # should return the mean square error between the actual y and predicted y

  # Write your code here ----------
  A=np.square(y-y_pred)
  #error=((np.square(y-y_pred)).sum)/(2*y.size)
  # -------------------------------

  return np.sum(A)/(2*y.size)

# %%
def train_by_algebra(X, y):
  # should return the trained weight 'W' using the linear algebra method i.e. setting dE/dW = 0

  # Write your code here ----------
  A=np.linalg.inv(np.dot(X.T,X))
  A=np.dot(A,X.T)
  W=np.dot(A,y)
  
  
  # -------------------------------

  return W

# %%
def train_by_GD(X, y, epochs=5, lr=0.01):
  # should return the trained weight 'W' using the gradient descent for number of iterations equals to epochs
  # should also return error history int the cariable error_hist.shape = (epochs,); error_hist[i] = mean square error after epoch i-1
  # should also print mean square error after each epoch/ iteration
  # lr = "learning rate" i.e. eta
  W=np.zeros(np.dot(X.T,y).shape)
  error_hist=[]
  for i in range(0,epochs-1):
    A=np.dot(X.T,np.dot(X,W)-y)
    W=W-lr*A
    error_hist.append(MSE(y,np.dot(X,W)))
    
  # Write your code here ----------
   
  # -------------------------------

  return W, error_hist

# %% [markdown]
# ### Now write a complete code using the function defined above to learn the model for following cases:

# %% [markdown]
# ##### Learn **W** using linear algebra method and prints mean square error between actual y and predicted y. Use `y_pred = XW`. Also plot y_pred and y on different plots.

# %%
# Write your code here ----------
X,y=load_data_LR()
W= train_by_algebra(X, y)
y_pred=np.dot(X,W)
MSE(y,y_pred)
plt.plot(X,y)
plt.xlabel('X')
plt.ylabel('Actual Y')
plt.show()
plt.plot(X,y_pred)
plt.xlabel('X')
plt.ylabel('Predicted Y')
plt.show()
# -------------------------------

# %% [markdown]
# ##### Learn **W** using gradient descent method for following learning rates, `lr = [0.01, 0.001, 0.0001]` for **10 epochs**. Plot **MSE vs epochs** for each of them.  Also plot y_pred and y on different plots.

# %%
# Write your code here ----------
X,y=load_data_LR()
arr=[]
for i in range(1,11):
   W, error_hist=train_by_GD(X, y, i, lr=0.01)
   y_pred=np.dot(X,W)
   arr.append(MSE(y,y_pred))

plt.plot(X,y)
plt.xlabel('X')
plt.ylabel('Actual Y')
plt.show()
plt.plot(X,y_pred)
plt.text(1,0.8*1e6, 'lr=0.01', fontsize = 12)
plt.xlabel('X')
plt.ylabel('Predicted Y')
plt.show()
plt.plot(range(1,11),arr)
plt.xlabel('epochs')
plt.ylabel('MSE')
plt.text(1,0.8*1e6, 'lr=0.01', fontsize = 12)
plt.show()

arr=[]
for i in range(1,11):
   W, error_hist=train_by_GD(X, y, i, lr=0.001)
   y_pred=np.dot(X,W)
   arr.append(MSE(y,y_pred))

plt.plot(X,y_pred)
plt.text(1,20, 'lr=0.001', fontsize = 12)
plt.xlabel('X')
plt.ylabel('Predicted Y')
plt.show()
plt.plot(range(1,11),arr)
plt.xlabel('epochs')
plt.ylabel('MSE')
plt.text(1,20, 'lr=0.001', fontsize = 12)
plt.show()

arr=[]
for i in range(1,11):
   W, error_hist=train_by_GD(X, y, i, lr=0.001)
   y_pred=np.dot(X,W)
   arr.append(MSE(y,y_pred))


plt.plot(X,y_pred)
plt.text(1,20, 'lr=0.0001', fontsize = 12)
plt.xlabel('X')
plt.ylabel('Predicted Y')
plt.show()
plt.plot(range(1,11),arr)
plt.xlabel('epochs')
plt.ylabel('MSE')
plt.text(1,20, 'lr=0.0001', fontsize = 12)
plt.show()
# -------------------------------

# %% [markdown]
# ## Question 2: Image Classification in Tensorflow using Deep Learning
# To check whether you are able to build a given neural network model in tensorflow or not. First we will build a fully connected NN model second we will build a CNN model.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
def plot_history(history):
  # function to plot accuracy vs epoch

  plt.plot(history.history['accuracy'], label='accuracy')
  plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(loc='lower right')

# %%
def load_data_cifar10_norm():
  # should return the normalised cifar10 dataset by loading it from tensorflow
  # link: https://www.tensorflow.org/api_docs/python/tf/keras/datasets/cifar10/

  # Write your code here ----------
  (x_train,y_train),(x_test,y_test)=tf.keras.datasets.cifar10.load_data()
  x_train=x_train/255
  x_test=x_test/255
  # -------------------------------

  return x_train, y_train, x_test, y_test

# %% [markdown]
# ### Define a fully connected neural network model with following attributes:
#
# *   Total number of **hidden layers = 4**, all with **relu** activation
# *   Number of neurons in **first hidden layer = 7200**
# *   Number of neurons in **second hidden layer = 2304**
# *   Number of neurons in **third hidden layer = 1024**
# *   Number of neurons in **fourth hidden layer = 64**

# %%
def build_fc_model(input_shape=(32, 32, 3), num_class=10):
  # should return a sequential model defined based on the above attributes
  # do not compile the model
  model=tf.keras.models.Sequential([
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(7200,activation='relu',input_shape=input_shape),
        tf.keras.layers.Dense(2304,activation='relu'),
        tf.keras.layers.Dense(1024,activation='relu'),
        tf.keras.layers.Dense(64,activation='relu'),
        tf.keras.layers.Dense(10,activation='softmax')
  ])
  # Write your code here ----------

  # -------------------------------

  return model

# %% [markdown]
# ### Define a CNN model with following attribute:
#
# *   Total number of **hidden layer = 4**
# *   After every convolutional layer there must be a MaxPoolingLayer of size (2, 2)
# *   Total number of convolutional layer = 3, all with **relu** activation.
#     *    Number of filters in **first convolutional layer = 32**
#     *    Number of filters in **second convolutional layer = 64**
#     *    Number of filters in **third convolutional layer = 64**
# *   After all convolutional layer flatten the output and use **dense layer of 64 neurons**

# %%
def build_cnn_model(input_shape=(32, 32, 3), num_class=10):
  # should return a sequential model defined based on the above attributes
  # do not compile the model

  # Write your code here ----------
  model=tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=input_shape),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(64,activation='relu'),
        tf.keras.layers.Dense(10,activation='softmax')

  ])
  # -------------------------------

  return model

# %% [markdown]
# ### Compile and train the fully connected neural network model using the above functions.

# %%
# Write your code here ----------
model=build_fc_model(input_shape=(32, 32, 3), num_class=10) 
model.compile(loss='sparse_categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

# -------------------------------
x_train,y_train,x_test,y_test=load_data_cifar10_norm()
history = model.fit(x_train, y_train, epochs=10, batch_size=512,
                    validation_data=(x_test, y_test))

plot_history(history)
model.summary()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# Epoch 1/10
# 98/98 [==============================] - 8s 41ms/step - loss: 5.3835 - accuracy: 0.1266 - val_loss: 2.2724 - val_accuracy: 0.1554
# Epoch 2/10
# 98/98 [==============================] - 4s 39ms/step - loss: 2.2063 - accuracy: 0.1724 - val_loss: 2.1501 - val_accuracy: 0.2087
# Epoch 3/10
# 98/98 [==============================] - 4s 38ms/step - loss: 2.0916 - accuracy: 0.2306 - val_loss: 1.9462 - val_accuracy: 0.2829
# Epoch 4/10
# 98/98 [==============================] - 4s 38ms/step - loss: 1.9696 - accuracy: 0.2824 - val_loss: 1.9237 - val_accuracy: 0.3063
# Epoch 5/10
# 98/98 [==============================] - 4s 38ms/step - loss: 1.9115 - accuracy: 0.3084 - val_loss: 1.9001 - val_accuracy: 0.3200
# Epoch 6/10
# 98/98 [==============================] - 4s 38ms/step - loss: 1.8639 - accuracy: 0.3279 - val_loss: 1.8011 - val_accuracy: 0.3346
# Epoch 7/10
# 98/98 [==============================] - 4s 38ms/step - loss: 1.8097 - accuracy: 0.3487 - val_loss: 1.7501 - val_accuracy: 0.3796
# Epoch 8/10
# 98/98 [==============================] - 4s 38ms/step - loss: 1.7810 - accuracy: 0.3612 - val_loss: 1.7679 - val_accuracy: 0.3772
# Epoch 9/10
# 98/98 [==============================] - 4s 38ms/step - loss: 1.7435 - accuracy: 0.3765 - val_loss: 1.6765 - val_accuracy: 0.3969
# Epoch 10/10
# 98/98 [==============================] - 4s 39ms/step - loss: 1.7095 - accuracy: 0.3867 - val_loss: 1.6489 - val_accuracy: 0.4021
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 3072)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 3072)              0
# _________________________________________________________________
# dense (Dense)                (None, 7200)              22125600
# _________________________________________________________________
# dense_1 (Dense)              (None, 2304)              16591104
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2360320
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                65600
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                650
# =================================================================
# Total params: 41,143,274
# Trainable params: 41,143,274
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile and train the CNN model using the above functions.

# %%
# Write your code here ----------
model=build_cnn_model(input_shape=(32, 32, 3), num_class=10)
model.compile(loss='sparse_categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
# -------------------------------
x_train,y_train,x_test,y_test=load_data_cifar10_norm()
history = model.fit(x_train, y_train, epochs=10, batch_size=512,
                    validation_data=(x_test, y_test))

plot_history(history)
model.summary()
# Out:
# Epoch 1/10
# 98/98 [==============================] - 31s 22ms/step - loss: 2.0689 - accuracy: 0.2303 - val_loss: 1.8141 - val_accuracy: 0.3544
# Epoch 2/10
# 98/98 [==============================] - 2s 16ms/step - loss: 1.8103 - accuracy: 0.3388 - val_loss: 1.6399 - val_accuracy: 0.4067
# Epoch 3/10
# 98/98 [==============================] - 2s 16ms/step - loss: 1.6904 - accuracy: 0.3864 - val_loss: 1.6060 - val_accuracy: 0.3999
# Epoch 4/10
# 98/98 [==============================] - 2s 16ms/step - loss: 1.6086 - accuracy: 0.4158 - val_loss: 1.4971 - val_accuracy: 0.4620
# Epoch 5/10
# 98/98 [==============================] - 2s 16ms/step - loss: 1.5428 - accuracy: 0.4458 - val_loss: 1.4088 - val_accuracy: 0.4882
# Epoch 6/10
# 98/98 [==============================] - 2s 16ms/step - loss: 1.4849 - accuracy: 0.4650 - val_loss: 1.5143 - val_accuracy: 0.4557
# Epoch 7/10
# 98/98 [==============================] - 2s 16ms/step - loss: 1.4378 - accuracy: 0.4837 - val_loss: 1.4500 - val_accuracy: 0.4999
# Epoch 8/10
# 98/98 [==============================] - 2s 16ms/step - loss: 1.3961 - accuracy: 0.4995 - val_loss: 1.2645 - val_accuracy: 0.5505
# Epoch 9/10
# 98/98 [==============================] - 2s 16ms/step - loss: 1.3520 - accuracy: 0.5186 - val_loss: 1.3281 - val_accuracy: 0.5339
# Epoch 10/10
# 98/98 [==============================] - 2s 16ms/step - loss: 1.3285 - accuracy: 0.5261 - val_loss: 1.2543 - val_accuracy: 0.5481
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                650
# =================================================================
# Total params: 73,418
# Trainable params: 73,418
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### What do you observe? Compare both the model by looking at their Accuracy vs Epoch plot and total numbers of trainable parameters.

# %%
print("The number of params in CNN is much less than number of params in NN.We can also observe that CNN's val_accuracy is 58% and NN's val_accuracy is 40% only.")
# Out:
# Replace this with your observation
